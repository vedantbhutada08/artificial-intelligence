# %% [markdown]
# #Name: Vedant Bhutada
# #Batch: A4
# #Roll: 69
# #Aim: Write a program to solve Tic-Tac-Toe using min-max algorithm

# %% [markdown]
# #X plays first

# %%
from collections import deque

class Node:
    def __init__(self, board, player):
        self.board = board
        self.player = player
        self.children = []
        self.score = None

    def add_child(self, node):
        self.children.append(node)


def print_board(board):
    for row in board:
        print(' | '.join(row))
        print('-' * 10)


def check_winner(board, player):
    for i in range(3):
        if all(cell == player for cell in board[i]) or all(board[j][i] == player for j in range(3)):
            return True
    if all(board[i][i] == player for i in range(3)) or all(board[i][2 - i] == player for i in range(3)):
        return True
    return False


def evaluate(board):
    if check_winner(board, 'X'):
        return 1
    elif check_winner(board, 'O'):
        return -1
    elif all(cell != ' ' for row in board for cell in row):
        return 0
    else:
        return None


def get_available_moves(board):
    return [(i, j) for i in range(3) for j in range(3) if board[i][j] == ' ']


def build_game_tree(node, player):
    evaluation = evaluate(node.board)
    if evaluation is not None:
        node.score = evaluation
        return

    for move in get_available_moves(node.board):
        new_board = [row[:] for row in node.board]
        new_board[move[0]][move[1]] = player
        new_node = Node(new_board, 'X' if player == 'O' else 'O')
        node.add_child(new_node)
        build_game_tree(new_node, 'X' if player == 'O' else 'O')

    node.score = max(child.score for child in node.children) if node.player == 'X' else min(child.score for child in node.children)


def print_max_then_min_tree(node):
    queue = deque([node])
    while queue:
        current_node = queue.popleft()
        print(f"{current_node.player} plays:")
        print_board(current_node.board)
        print(f"Evaluation: {current_node.score}")
        queue.extend(current_node.children)

initial_board = [
    [' ', 'O', 'X'],
    ['O', ' ', 'X'],
    ['O', 'X', ' ']
]

root = Node(initial_board, 'X')
build_game_tree(root, 'X')
print_max_then_min_tree(root)
# Out:
# X plays:
#   | O | X
# ----------
# O |   | X
# ----------
# O | X |
# ----------
# Evaluation: 1
# O plays:
# X | O | X
# ----------
# O |   | X
# ----------
# O | X |
# ----------
# Evaluation: 0
# O plays:
#   | O | X
# ----------
# O | X | X
# ----------
# O | X |
# ----------
# Evaluation: -1
# O plays:
#   | O | X
# ----------
# O |   | X
# ----------
# O | X | X
# ----------
# Evaluation: 1
# X plays:
# X | O | X
# ----------
# O | O | X
# ----------
# O | X |
# ----------
# Evaluation: 1
# X plays:
# X | O | X
# ----------
# O |   | X
# ----------
# O | X | O
# ----------
# Evaluation: 0
# X plays:
# O | O | X
# ----------
# O | X | X
# ----------
# O | X |
# ----------
# Evaluation: -1
# X plays:
#   | O | X
# ----------
# O | X | X
# ----------
# O | X | O
# ----------
# Evaluation: 0
# O plays:
# X | O | X
# ----------
# O | O | X
# ----------
# O | X | X
# ----------
# Evaluation: 1
# O plays:
# X | O | X
# ----------
# O | X | X
# ----------
# O | X | O
# ----------
# ...

# %%
class Node:
    def __init__(self, board, player):
        self.board = board
        self.player = player
        self.children = []
        self.score = None

    def add_child(self, node):
        self.children.append(node)


def print_board(board):
    for row in board:
        print(' | '.join(row))
        print('-' * 10)


def check_winner(board, player):
    for i in range(3):
        if all(cell == player for cell in board[i]) or all(board[j][i] == player for j in range(3)):
            return True
    if all(board[i][i] == player for i in range(3)) or all(board[i][2 - i] == player for i in range(3)):
        return True
    return False


def evaluate(board):
    if check_winner(board, 'X'):
        return 1
    elif check_winner(board, 'O'):
        return -1
    elif all(cell != ' ' for row in board for cell in row):
        return 0
    else:
        return None


def get_available_moves(board):
    return [(i, j) for i in range(3) for j in range(3) if board[i][j] == ' ']


def build_game_tree(node, player):
    evaluation = evaluate(node.board)
    if evaluation is not None:
        node.score = evaluation
        return

    for move in get_available_moves(node.board):
        new_board = [row[:] for row in node.board]
        new_board[move[0]][move[1]] = player
        new_node = Node(new_board, 'X' if player == 'O' else 'O')
        node.add_child(new_node)
        build_game_tree(new_node, 'X' if player == 'O' else 'O')

    node.score = max(child.score for child in node.children) if node.player == 'X' else min(child.score for child in node.children)


def print_max_then_min_tree(node, depth=0):
    print(depth * '  ' + f"{node.player} plays:")
    print_board(node.board)
    print(depth * '  ' + f"Evaluation: {node.score}")
    for child in node.children:
        print_max_then_min_tree(child, depth + 1)

initial_board = [
    [' ', 'O', 'X'],
    ['O', ' ', 'X'],
    ['O', 'X', ' ']
]

root = Node(initial_board, 'X')

build_game_tree(root, 'X')

print_max_then_min_tree(root)
# Out:
# X plays:
#   | O | X
# ----------
# O |   | X
# ----------
# O | X |
# ----------
# Evaluation: 1
#   O plays:
# X | O | X
# ----------
# O |   | X
# ----------
# O | X |
# ----------
#   Evaluation: 0
#     X plays:
# X | O | X
# ----------
# O | O | X
# ----------
# O | X |
# ----------
#     Evaluation: 1
#       O plays:
# X | O | X
# ----------
# O | O | X
# ----------
# O | X | X
# ----------
#       Evaluation: 1
#     X plays:
# X | O | X
# ----------
# O |   | X
# ----------
# O | X | O
# ----------
#     Evaluation: 0
#       O plays:
# X | O | X
# ----------
# O | X | X
# ----------
# O | X | O
# ----------
#       Evaluation: 0
#   O plays:
#   | O | X
# ----------
# O | X | X
# ----------
# O | X |
# ----------
#   Evaluation: -1
#     X plays:
# O | O | X
# ----------
# O | X | X
# ----------
# O | X |
# ----------
#     Evaluation: -1
#     X plays:
#   | O | X
# ----------
# O | X | X
# ----------
# O | X | O
# ----------
#     Evaluation: 0
#       O plays:
# ...

# %% [markdown]
# #O plays first

# %%
class Node:
    def __init__(self, board, player):
        self.board = board
        self.player = player
        self.children = []
        self.score = None

    def add_child(self, node):
        self.children.append(node)


def print_board(board):
    for row in board:
        print(' | '.join(row))
        print('-' * 5)


def check_winner(board, player):
    for i in range(3):
        if all(cell == player for cell in board[i]) or all(board[j][i] == player for j in range(3)):
            return True
    if all(board[i][i] == player for i in range(3)) or all(board[i][2 - i] == player for i in range(3)):
        return True
    return False


def evaluate(board):
    if check_winner(board, 'X'):
        return 1
    elif check_winner(board, 'O'):
        return -1
    elif all(cell != ' ' for row in board for cell in row):
        return 0
    else:
        return None


def get_available_moves(board):
    return [(i, j) for i in range(3) for j in range(3) if board[i][j] == ' ']


def build_game_tree(node, player):
    evaluation = evaluate(node.board)
    if evaluation is not None:
        node.score = evaluation
        return

    for move in get_available_moves(node.board):
        new_board = [row[:] for row in node.board]
        new_board[move[0]][move[1]] = player
        new_node = Node(new_board, 'X' if player == 'O' else 'O')
        node.add_child(new_node)
        build_game_tree(new_node, 'X' if player == 'O' else 'O')

    node.score = max(child.score for child in node.children) if node.player == 'X' else min(child.score for child in node.children)


def print_max_then_min_tree(node, depth=0):
    print(depth * '  ' + f"{node.player} plays:")
    print_board(node.board)
    print(depth * '  ' + f"Evaluation: {node.score}")
    for child in node.children:
        print_max_then_min_tree(child, depth + 1)

initial_board = [
    ['X', 'O', 'X'],
    ['O', ' ', 'X'],
    ['O', 'X', ' ']
]

root = Node(initial_board, 'O')
build_game_tree(root, 'O')

print_max_then_min_tree(root)
# Out:
# O plays:
# X | O | X
# -----
# O |   | X
# -----
# O | X |
# -----
# Evaluation: 0
#   X plays:
# X | O | X
# -----
# O | O | X
# -----
# O | X |
# -----
#   Evaluation: 1
#     O plays:
# X | O | X
# -----
# O | O | X
# -----
# O | X | X
# -----
#     Evaluation: 1
#   X plays:
# X | O | X
# -----
# O |   | X
# -----
# O | X | O
# -----
#   Evaluation: 0
#     O plays:
# X | O | X
# -----
# O | X | X
# -----
# O | X | O
# -----
#     Evaluation: 0
